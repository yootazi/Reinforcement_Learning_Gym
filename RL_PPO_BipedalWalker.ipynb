# %% [markdown]
# <a href="https://colab.research.google.com/github/yootazi/Reinforcement_Learning_Gym/blob/main/RL_PPO_BipedalWalker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Bipedal Walker
#
# Action Space: Box(-1.0, 1.0, (4,), float32)
# Observation Space: (24,)
#
# import: gym.make("BipedalWalker-v3")
# Algorithm: PPO
# Policy:"Mlp"

# %% [markdown]
# # 1. Import dependencies

# %%
pip install git+https://github.com/DLR-RM/stable-baselines3

# %%
# !pip3 install box2d-py
# !pip3 install gym[Box_2D]

# %%
import gym
import torch
import os
import tensorflow as tf
from stable_baselines3 import SAC, TD3
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Setup the Environment

# %%
env = gym.make("BipedalWalker-v3")

# %%
episodes = 5  # testing the environment 5 times 
for episode in range(1, episodes+1):
    obs = env.reset()  # reseting environment by getting an array of 4 initial set of observations of that perticular environment
    done = False
    score = 0 
    
    while not done:  
        #env.render(mode='human')  # to view the graphical representation of environment (does not work)
        action = env.action_space.sample()  # generating a random action, 0 or 1 - here action_space is Discrete(2) -> {0, 1}
        obs, reward, done, info = env.step(action)  # passing random action to environment (passing 0 or 1)
        score+=reward  # accumulating rewards
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:1 Score:-99.4896033230933
# Episode:2 Score:-108.94805569125204
# Episode:3 Score:-87.53951255855898
# Episode:4 Score:-103.27160644020482
# Episode:5 Score:-109.39670468833981

# %% [markdown]
# # 2.2 Vectorizing the Environment and Training the Model

# %% [markdown]
# RL Algorithms:
#     1. Model-Based - predict future states to generate best possible action
#         1. Learn the Model
#         2. Given the Model --> AlphaZero
#     2. Model-Free ( a lot of developments are happening) - uses current state to make predictions
#         1.Policiy Optimization --> PPO (Proximal Policy Optimization ) / A2C / DQN
#         2.Q-Learning
# using best algorithms based on the action space in Stable Baseline:
#     A2C - works on all types of action space (Box, Discrete, MultiDistricrete, MultiBinary, MultiProcessing)
#     PPO - works on all types of action space (Box, Discrete, MultiDistricrete, MultiBinary, MultiProcessing)
#     DQN - only on Discrete

# %%
log_path = os.path.join('Training', 'Logs')  # define a log_path where we can monitor the performance of the model
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log = log_path)  # defining the model - defining the policiy (multulayer perceptron policy (standard NN))
model.learn(total_timesteps=1000000) # 1M
# Out:
# Streaming output truncated to the last 5000 lines.
# |    loss                 | 1.86      |
# |    n_updates            | 2610      |
# |    policy_gradient_loss | -0.0113   |
# |    std                  | 0.341     |
# |    value_loss           | 6.15      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 263         |
# |    time_elapsed         | 1209        |
# |    total_timesteps      | 538624      |
# | train/                  |             |
# |    approx_kl            | 0.020912768 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0995      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.345       |
# |    n_updates            | 2620        |
# |    policy_gradient_loss | -0.00545    |
# |    std                  | 0.342       |
# |    value_loss           | 4.75        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 264         |
# |    time_elapsed         | 1214        |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.020421758 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.488       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.45        |
# |    n_updates            | 2630        |
# |    policy_gradient_loss | -0.00483    |
# |    std                  | 0.34        |
# |    value_loss           | 4.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 265         |
# |    time_elapsed         | 1218        |
# |    total_timesteps      | 542720      |
# | train/                  |             |
# |    approx_kl            | 0.018824313 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.708       |
# |    n_updates            | 2640        |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.339       |
# |    value_loss           | 11.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 266         |
# |    time_elapsed         | 1223        |
# |    total_timesteps      | 544768      |
# | train/                  |             |
# |    approx_kl            | 0.022035653 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.771      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.24        |
# |    n_updates            | 2650        |
# |    policy_gradient_loss | -0.0075     |
# |    std                  | 0.338       |
# |    value_loss           | 11.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 267         |
# |    time_elapsed         | 1227        |
# |    total_timesteps      | 546816      |
# | train/                  |             |
# |    approx_kl            | 0.020251703 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.78        |
# |    n_updates            | 2660        |
# |    policy_gradient_loss | -0.00692    |
# |    std                  | 0.337       |
# |    value_loss           | 9.79        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | 216         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 268         |
# |    time_elapsed         | 1232        |
# |    total_timesteps      | 548864      |
# | train/                  |             |
# |    approx_kl            | 0.022221632 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.612       |
# |    n_updates            | 2670        |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.337       |
# |    value_loss           | 7.57        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | 216         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 269         |
# |    time_elapsed         | 1237        |
# |    total_timesteps      | 550912      |
# | train/                  |             |
# |    approx_kl            | 0.020949565 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.66        |
# |    n_updates            | 2680        |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.335       |
# |    value_loss           | 9.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 270         |
# |    time_elapsed         | 1241        |
# |    total_timesteps      | 552960      |
# | train/                  |             |
# |    approx_kl            | 0.011799153 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.76        |
# |    n_updates            | 2690        |
# |    policy_gradient_loss | -0.00854    |
# |    std                  | 0.333       |
# |    value_loss           | 12.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.03e+03   |
# |    ep_rew_mean          | 209        |
# | time/                   |            |
# |    fps                  | 445        |
# |    iterations           | 271        |
# |    time_elapsed         | 1247       |
# |    total_timesteps      | 555008     |
# | train/                  |            |
# |    approx_kl            | 0.00788248 |
# |    clip_fraction        | 0.0896     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.927      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21         |
# |    n_updates            | 2700       |
# |    policy_gradient_loss | -0.00913   |
# |    std                  | 0.332      |
# |    value_loss           | 30.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.03e+03   |
# |    ep_rew_mean          | 209        |
# | time/                   |            |
# |    fps                  | 445        |
# |    iterations           | 272        |
# |    time_elapsed         | 1251       |
# |    total_timesteps      | 557056     |
# | train/                  |            |
# |    approx_kl            | 0.02937884 |
# |    clip_fraction        | 0.338      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.24      |
# |    explained_variance   | -0.147     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.881      |
# |    n_updates            | 2710       |
# |    policy_gradient_loss | -0.00282   |
# |    std                  | 0.331      |
# |    value_loss           | 5.86       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 209         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 273         |
# |    time_elapsed         | 1256        |
# |    total_timesteps      | 559104      |
# | train/                  |             |
# |    approx_kl            | 0.023419905 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.71        |
# |    n_updates            | 2720        |
# |    policy_gradient_loss | -0.00639    |
# |    std                  | 0.335       |
# |    value_loss           | 5.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 274         |
# |    time_elapsed         | 1260        |
# |    total_timesteps      | 561152      |
# | train/                  |             |
# |    approx_kl            | 0.023807254 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.187       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.14        |
# |    n_updates            | 2730        |
# |    policy_gradient_loss | -0.00812    |
# |    std                  | 0.334       |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 275         |
# |    time_elapsed         | 1265        |
# |    total_timesteps      | 563200      |
# | train/                  |             |
# |    approx_kl            | 0.018951058 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.64        |
# |    n_updates            | 2740        |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.335       |
# |    value_loss           | 7.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 276         |
# |    time_elapsed         | 1269        |
# |    total_timesteps      | 565248      |
# | train/                  |             |
# |    approx_kl            | 0.032699607 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.787       |
# |    n_updates            | 2750        |
# |    policy_gradient_loss | -0.00859    |
# |    std                  | 0.331       |
# |    value_loss           | 5.66        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 277         |
# |    time_elapsed         | 1274        |
# |    total_timesteps      | 567296      |
# | train/                  |             |
# |    approx_kl            | 0.025479691 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.378       |
# |    n_updates            | 2760        |
# |    policy_gradient_loss | -0.00763    |
# |    std                  | 0.332       |
# |    value_loss           | 4.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 278         |
# |    time_elapsed         | 1279        |
# |    total_timesteps      | 569344      |
# | train/                  |             |
# |    approx_kl            | 0.023657378 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.433       |
# |    n_updates            | 2770        |
# |    policy_gradient_loss | -0.00599    |
# |    std                  | 0.333       |
# |    value_loss           | 2.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 279         |
# |    time_elapsed         | 1283        |
# |    total_timesteps      | 571392      |
# | train/                  |             |
# |    approx_kl            | 0.019807719 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07        |
# |    n_updates            | 2780        |
# |    policy_gradient_loss | -0.00852    |
# |    std                  | 0.332       |
# |    value_loss           | 5.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 280         |
# |    time_elapsed         | 1288        |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.029728815 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.485       |
# |    n_updates            | 2790        |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.331       |
# |    value_loss           | 5.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 281         |
# |    time_elapsed         | 1292        |
# |    total_timesteps      | 575488      |
# | train/                  |             |
# |    approx_kl            | 0.023276495 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59        |
# |    n_updates            | 2800        |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.331       |
# |    value_loss           | 4.92        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 282         |
# |    time_elapsed         | 1297        |
# |    total_timesteps      | 577536      |
# | train/                  |             |
# |    approx_kl            | 0.018732542 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.291       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.62        |
# |    n_updates            | 2810        |
# |    policy_gradient_loss | -0.00564    |
# |    std                  | 0.329       |
# |    value_loss           | 5.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 283         |
# |    time_elapsed         | 1301        |
# |    total_timesteps      | 579584      |
# | train/                  |             |
# |    approx_kl            | 0.025807682 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.217       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.309       |
# |    n_updates            | 2820        |
# |    policy_gradient_loss | -0.00728    |
# |    std                  | 0.329       |
# |    value_loss           | 3           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 284         |
# |    time_elapsed         | 1306        |
# |    total_timesteps      | 581632      |
# | train/                  |             |
# |    approx_kl            | 0.027739704 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.26        |
# |    n_updates            | 2830        |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.328       |
# |    value_loss           | 4.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 219         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 285         |
# |    time_elapsed         | 1311        |
# |    total_timesteps      | 583680      |
# | train/                  |             |
# |    approx_kl            | 0.023870006 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.356       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.74        |
# |    n_updates            | 2840        |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.328       |
# |    value_loss           | 5.82        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 227         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 286         |
# |    time_elapsed         | 1315        |
# |    total_timesteps      | 585728      |
# | train/                  |             |
# |    approx_kl            | 0.023265187 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.449       |
# |    n_updates            | 2850        |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.327       |
# |    value_loss           | 5.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 227         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 287         |
# |    time_elapsed         | 1320        |
# |    total_timesteps      | 587776      |
# | train/                  |             |
# |    approx_kl            | 0.021960173 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.85        |
# |    n_updates            | 2860        |
# |    policy_gradient_loss | -0.00643    |
# |    std                  | 0.327       |
# |    value_loss           | 5.38        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 227         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 288         |
# |    time_elapsed         | 1324        |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.019657642 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.507       |
# |    n_updates            | 2870        |
# |    policy_gradient_loss | -0.00953    |
# |    std                  | 0.325       |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 229         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 289         |
# |    time_elapsed         | 1329        |
# |    total_timesteps      | 591872      |
# | train/                  |             |
# |    approx_kl            | 0.024236498 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.192       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.484       |
# |    n_updates            | 2880        |
# |    policy_gradient_loss | -0.00634    |
# |    std                  | 0.326       |
# |    value_loss           | 5.6         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.03e+03   |
# |    ep_rew_mean          | 232        |
# | time/                   |            |
# |    fps                  | 445        |
# |    iterations           | 290        |
# |    time_elapsed         | 1334       |
# |    total_timesteps      | 593920     |
# | train/                  |            |
# |    approx_kl            | 0.02769161 |
# |    clip_fraction        | 0.271      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.373      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.303      |
# |    n_updates            | 2890       |
# |    policy_gradient_loss | -0.00793   |
# |    std                  | 0.329      |
# |    value_loss           | 4.95       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 236         |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 291         |
# |    time_elapsed         | 1339        |
# |    total_timesteps      | 595968      |
# | train/                  |             |
# |    approx_kl            | 0.020556565 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.746       |
# |    n_updates            | 2900        |
# |    policy_gradient_loss | -0.00681    |
# |    std                  | 0.333       |
# |    value_loss           | 5.44        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.05e+03   |
# |    ep_rew_mean          | 236        |
# | time/                   |            |
# |    fps                  | 444        |
# |    iterations           | 292        |
# |    time_elapsed         | 1344       |
# |    total_timesteps      | 598016     |
# | train/                  |            |
# |    approx_kl            | 0.02392931 |
# |    clip_fraction        | 0.261      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.894      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.55       |
# |    n_updates            | 2910       |
# |    policy_gradient_loss | -0.0114    |
# |    std                  | 0.333      |
# |    value_loss           | 4.77       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | 244         |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 293         |
# |    time_elapsed         | 1348        |
# |    total_timesteps      | 600064      |
# | train/                  |             |
# |    approx_kl            | 0.026744228 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.205       |
# |    n_updates            | 2920        |
# |    policy_gradient_loss | -0.00303    |
# |    std                  | 0.334       |
# |    value_loss           | 5.46        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.06e+03  |
# |    ep_rew_mean          | 243       |
# | time/                   |           |
# |    fps                  | 444       |
# |    iterations           | 294       |
# |    time_elapsed         | 1353      |
# |    total_timesteps      | 602112    |
# | train/                  |           |
# |    approx_kl            | 0.0240363 |
# |    clip_fraction        | 0.309     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.28     |
# |    explained_variance   | 0.175     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.49      |
# |    n_updates            | 2930      |
# |    policy_gradient_loss | -0.00674  |
# |    std                  | 0.337     |
# |    value_loss           | 5.79      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | 241         |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 295         |
# |    time_elapsed         | 1357        |
# |    total_timesteps      | 604160      |
# | train/                  |             |
# |    approx_kl            | 0.019268293 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.66        |
# |    n_updates            | 2940        |
# |    policy_gradient_loss | -0.00912    |
# |    std                  | 0.337       |
# |    value_loss           | 9.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | 241         |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 296         |
# |    time_elapsed         | 1362        |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.017442413 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.693       |
# |    n_updates            | 2950        |
# |    policy_gradient_loss | -0.00873    |
# |    std                  | 0.337       |
# |    value_loss           | 14.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | 241         |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 297         |
# |    time_elapsed         | 1366        |
# |    total_timesteps      | 608256      |
# | train/                  |             |
# |    approx_kl            | 0.014848486 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 2960        |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.335       |
# |    value_loss           | 13          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 238         |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 298         |
# |    time_elapsed         | 1371        |
# |    total_timesteps      | 610304      |
# | train/                  |             |
# |    approx_kl            | 0.024086399 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.0243      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.06        |
# |    n_updates            | 2970        |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.331       |
# |    value_loss           | 6.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 299         |
# |    time_elapsed         | 1376        |
# |    total_timesteps      | 612352      |
# | train/                  |             |
# |    approx_kl            | 0.027015183 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17        |
# |    n_updates            | 2980        |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.331       |
# |    value_loss           | 11.1        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.03e+03  |
# |    ep_rew_mean          | 234       |
# | time/                   |           |
# |    fps                  | 444       |
# |    iterations           | 300       |
# |    time_elapsed         | 1380      |
# |    total_timesteps      | 614400    |
# | train/                  |           |
# |    approx_kl            | 0.0261636 |
# |    clip_fraction        | 0.259     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.25     |
# |    explained_variance   | 0.903     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.01      |
# |    n_updates            | 2990      |
# |    policy_gradient_loss | -0.014    |
# |    std                  | 0.334     |
# |    value_loss           | 9.31      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 231         |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 301         |
# |    time_elapsed         | 1385        |
# |    total_timesteps      | 616448      |
# | train/                  |             |
# |    approx_kl            | 0.026153004 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.71        |
# |    n_updates            | 3000        |
# |    policy_gradient_loss | -0.00943    |
# |    std                  | 0.336       |
# |    value_loss           | 5.56        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 232         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 302         |
# |    time_elapsed         | 1389        |
# |    total_timesteps      | 618496      |
# | train/                  |             |
# |    approx_kl            | 0.014320546 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.703       |
# |    n_updates            | 3010        |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.336       |
# |    value_loss           | 6.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 303         |
# |    time_elapsed         | 1394        |
# |    total_timesteps      | 620544      |
# | train/                  |             |
# |    approx_kl            | 0.021810338 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.87        |
# |    n_updates            | 3020        |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.337       |
# |    value_loss           | 9.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 304         |
# |    time_elapsed         | 1398        |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.020383451 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.72        |
# |    n_updates            | 3030        |
# |    policy_gradient_loss | -0.00838    |
# |    std                  | 0.337       |
# |    value_loss           | 8.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 305         |
# |    time_elapsed         | 1403        |
# |    total_timesteps      | 624640      |
# | train/                  |             |
# |    approx_kl            | 0.028776089 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.61        |
# |    n_updates            | 3040        |
# |    policy_gradient_loss | -0.00492    |
# |    std                  | 0.337       |
# |    value_loss           | 3.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 306         |
# |    time_elapsed         | 1408        |
# |    total_timesteps      | 626688      |
# | train/                  |             |
# |    approx_kl            | 0.026430776 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.75        |
# |    n_updates            | 3050        |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.338       |
# |    value_loss           | 6.21        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.01e+03   |
# |    ep_rew_mean          | 227        |
# | time/                   |            |
# |    fps                  | 445        |
# |    iterations           | 307        |
# |    time_elapsed         | 1412       |
# |    total_timesteps      | 628736     |
# | train/                  |            |
# |    approx_kl            | 0.01808231 |
# |    clip_fraction        | 0.19       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.8       |
# |    n_updates            | 3060       |
# |    policy_gradient_loss | -0.0059    |
# |    std                  | 0.339      |
# |    value_loss           | 31.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 227         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 308         |
# |    time_elapsed         | 1417        |
# |    total_timesteps      | 630784      |
# | train/                  |             |
# |    approx_kl            | 0.018174965 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.47        |
# |    n_updates            | 3070        |
# |    policy_gradient_loss | -0.00721    |
# |    std                  | 0.339       |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 229         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 309         |
# |    time_elapsed         | 1421        |
# |    total_timesteps      | 632832      |
# | train/                  |             |
# |    approx_kl            | 0.014978493 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.78        |
# |    n_updates            | 3080        |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.339       |
# |    value_loss           | 13.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.01e+03   |
# |    ep_rew_mean          | 229        |
# | time/                   |            |
# |    fps                  | 445        |
# |    iterations           | 310        |
# |    time_elapsed         | 1426       |
# |    total_timesteps      | 634880     |
# | train/                  |            |
# |    approx_kl            | 0.02601075 |
# |    clip_fraction        | 0.296      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.55       |
# |    n_updates            | 3090       |
# |    policy_gradient_loss | -0.00643   |
# |    std                  | 0.341      |
# |    value_loss           | 14.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 311         |
# |    time_elapsed         | 1431        |
# |    total_timesteps      | 636928      |
# | train/                  |             |
# |    approx_kl            | 0.029259576 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.03        |
# |    n_updates            | 3100        |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.34        |
# |    value_loss           | 7.96        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 224         |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 312         |
# |    time_elapsed         | 1436        |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.017309925 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.88        |
# |    n_updates            | 3110        |
# |    policy_gradient_loss | -0.00718    |
# |    std                  | 0.336       |
# |    value_loss           | 19          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 226         |
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 313         |
# |    time_elapsed         | 1440        |
# |    total_timesteps      | 641024      |
# | train/                  |             |
# |    approx_kl            | 0.026216477 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83        |
# |    n_updates            | 3120        |
# |    policy_gradient_loss | -0.0098     |
# |    std                  | 0.337       |
# |    value_loss           | 4.6         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 226       |
# | time/                   |           |
# |    fps                  | 444       |
# |    iterations           | 314       |
# |    time_elapsed         | 1445      |
# |    total_timesteps      | 643072    |
# | train/                  |           |
# |    approx_kl            | 0.0327535 |
# |    clip_fraction        | 0.356     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.29     |
# |    explained_variance   | 0.217     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.577     |
# |    n_updates            | 3130      |
# |    policy_gradient_loss | -0.00573  |
# |    std                  | 0.335     |
# ...
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18        |
# |    n_updates            | 4710        |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.316       |
# |    value_loss           | 19.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 924         |
# |    ep_rew_mean          | 212         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 473         |
# |    time_elapsed         | 2185        |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.039576873 |
# |    clip_fraction        | 0.351       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.8        |
# |    n_updates            | 4720        |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.318       |
# |    value_loss           | 6.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 934         |
# |    ep_rew_mean          | 216         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 474         |
# |    time_elapsed         | 2190        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.025553195 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.324       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.47        |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.00932    |
# |    std                  | 0.317       |
# |    value_loss           | 4.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 928         |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 475         |
# |    time_elapsed         | 2194        |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.026698224 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.0136      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.46        |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.00611    |
# |    std                  | 0.317       |
# |    value_loss           | 6.92        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 925         |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 476         |
# |    time_elapsed         | 2199        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.021581545 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.717       |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.00644    |
# |    std                  | 0.317       |
# |    value_loss           | 13.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 925         |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 477         |
# |    time_elapsed         | 2203        |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.031100726 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.73        |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.314       |
# |    value_loss           | 6.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 934         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 478         |
# |    time_elapsed         | 2208        |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.025308212 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.995      |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.86        |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.312       |
# |    value_loss           | 3.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 932         |
# |    ep_rew_mean          | 219         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 479         |
# |    time_elapsed         | 2212        |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.027198916 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | 0.142       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.25        |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00479    |
# |    std                  | 0.313       |
# |    value_loss           | 6.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 929         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 480         |
# |    time_elapsed         | 2217        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.023320267 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.07        |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.314       |
# |    value_loss           | 6.11        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 919        |
# |    ep_rew_mean          | 215        |
# | time/                   |            |
# |    fps                  | 443        |
# |    iterations           | 481        |
# |    time_elapsed         | 2221       |
# |    total_timesteps      | 985088     |
# | train/                  |            |
# |    approx_kl            | 0.02540721 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.917      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.69       |
# |    n_updates            | 4800       |
# |    policy_gradient_loss | -0.0109    |
# |    std                  | 0.313      |
# |    value_loss           | 6.42       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 919         |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 482         |
# |    time_elapsed         | 2226        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.031428874 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.315       |
# |    value_loss           | 15.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 918         |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 483         |
# |    time_elapsed         | 2230        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.027882382 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.91        |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00837    |
# |    std                  | 0.314       |
# |    value_loss           | 6.38        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 917         |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 484         |
# |    time_elapsed         | 2235        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.029794604 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.28        |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.317       |
# |    value_loss           | 6.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 917         |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 485         |
# |    time_elapsed         | 2239        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.020450626 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.0497      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.395       |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.00826    |
# |    std                  | 0.316       |
# |    value_loss           | 7.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 916         |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 486         |
# |    time_elapsed         | 2244        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.025939964 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33        |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.314       |
# |    value_loss           | 3.81        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 916        |
# |    ep_rew_mean          | 215        |
# | time/                   |            |
# |    fps                  | 443        |
# |    iterations           | 487        |
# |    time_elapsed         | 2248       |
# |    total_timesteps      | 997376     |
# | train/                  |            |
# |    approx_kl            | 0.03239949 |
# |    clip_fraction        | 0.286      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.218      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.2        |
# |    n_updates            | 4860       |
# |    policy_gradient_loss | -0.0105    |
# |    std                  | 0.316      |
# |    value_loss           | 6.56       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 916         |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 488         |
# |    time_elapsed         | 2253        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.025558677 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.618       |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.00982    |
# |    std                  | 0.314       |
# |    value_loss           | 6.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 920         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 489         |
# |    time_elapsed         | 2258        |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.021647304 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.42        |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.00989    |
# |    std                  | 0.313       |
# |    value_loss           | 5.8         |
# -----------------------------------------

# %% [markdown]
# # 4. Evaluation

# %%
# 300 points in 1600 time steps -> solved 
evaluate_policy(model, env, n_eval_episodes=10, render=False) # average reward
# Out:
# /usr/local/lib/python3.7/dist-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# (308.66683010110285, 0.890446320783785)

# %% [markdown]
# # 5. Save and Reload Model

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# save the trained model
save_dir = '/content/gdrive/MyDrive/RL_Models'
os.makedirs(save_dir, exist_ok=True)
model.save(save_dir + "/PPO_BipedalW_1M")

# %%
# save the trained model in zip 
import zipfile
archive = zipfile.ZipFile("/content/gdrive/MyDrive/RL_Models/PPO_BipedalW_1M.zip", 'r')
for f in archive.filelist:
  print(f.filename)
# Out:
# data
# pytorch_variables.pth
# policy.pth
# policy.optimizer.pth
# _stable_baselines3_version
# system_info.txt

# %%
del model

# %%
# load the trained model
model.load('/content/gdrive/MyDrive/RL_Models/PPO_BipedalW_1M')

# %%
# train again
model.learn(total_timesteps=1000000)

# %% [markdown]
#  # 6. Watching the Performance!

# %%
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install -U colabgymrender

# %%
# !apt-get install x11-utils > /dev/null 2>&1 and !pip install pyglet==v1.3.2

# %%
pip install xvfbwrapper

# %%
pip install gym[box2d]==0.17.* pyvirtualdisplay==0.2.* PyOpenGL==3.1.* PyOpenGL-accelerate==3.1.*

# %%
import gym
from colabgymrender.recorder import Recorder

env = gym.make("BipedalWalker-v3")
directory = './video'
env = Recorder(env, directory)

# %%
observation = env.reset()
terminal = False

while not terminal:
  action = env.action_space.sample()
  observation, reward, terminal, info = env.step(action)

env.play()

# %%
print(env.path)
